# %% [markdown]
# # Lesson 3 | Collaborative Branching and Merging: **<span style="color: purple;">Collaborator 2</span>**

# %% [markdown]
# Now that you understand individual branching, let's explore how teams collaborate. In this exercise, you will work in pairs to each develop a small feature on a separate branch, and then merge your work into a shared `master` branch.

# %% [markdown]
# <img src="attachment:a12f239f-2803-44bd-ab1d-4f581d1420b8.png" style="width: 80%;">
# https://www.neighborhoodindicators.org/library/catalog/introduction-git-and-github-slides

# %% [markdown]
# **Before you start, decide who will be **<span style="color: green;">Collaborator 1</span>** (the repository owner/creator) and who will be **<span style="color: purple;">Collaborator 2</span>** (the colleague) for this exercise.**
#
# ### **In this lesson, each of you will:**
# * Set up a new, shared remote GitHub repository for your team.
# * Push your local `master` branch to this remote (**<span style="color: green;">Collaborator 1</span>**) or clone it (**<span style="color: purple;">Collaborator 2</span>**).
# * Create your own feature branch: `feature/<collaborator1_name>_add-linear-regression`.
# * Make a distinct, non-conflicting change to `my_code.R` on your branch.
# * Push your feature branch to the remote.
# * Merge your feature branch into your local `master`.
# * Push your updated `master` to the remote.

# %%
# First, both parties set their working directory
# %cd ~/my_first_git_project

# %% [markdown]
# ## &nbsp;&nbsp; 3.1.&nbsp;&nbsp; What **<span style="color: purple;">Collaborator 2</span>** will do
#
# Now it's **<span style="color: purple;">Collaborator 2</span>**'s turn to contribute. Before you dive into your own edits, you'll need to get a copy of the shared project and make sure it's up-to-date with **<span style="color: green;">Collaborator 1</span>**'s latest changes from GitHub.
#
# **Here are the steps **<span style="color: purple;">Collaborator 2</span>** will follow in the upcoming cells:**
# - Clone the shared repository into your local **<span style="color: purple;">Collaborator 2</span>** workspace.
# - Pull the latest `master` branch from the remote (which should now include **<span style="color: green;">Collaborator 1</span>**'s changes).
# -  Create and switch to your feature branch: `feature/<collaborator2_name>_add-linear-regression`.
# - Modify `my_code.R` to add a linear regression line.
# - Commit your changes to your feature branch.
# - Push your feature branch to the shared remote.
# - Merge your feature branch into your local `master` and push the updated `master`.

# %% [markdown]
# ## &nbsp;&nbsp; 3.2.&nbsp;&nbsp; Clone the shared repository into your home directory.

# %% [markdown]
# Since **<span style="color: green;">Collaborator 1</span>** has established the shared repository (`penguin-collaboration-project`), **<span style="color: purple;">Collaborator 2</span>** will now clone it and add their specific version of `my_code.R` on a new branch to avoid overwriting their work immediately.
# <div style="margin-left: 30px;">
#
# 1. Navigate to your home directory in your **File Browser** or using `cd ~/`.
# 2. Open the **Git sidebar**.
# 3. Click the **Clone a Repository** button.
# 4. Paste the URL provided by your partner (e.g., `git@github.com:<Collaborator1_username>/penguin-collaboration-project.git`).
# 5. Click **Clone**.
# </div>

# %% [markdown]
# ## &nbsp;&nbsp; 3.3.&nbsp;&nbsp; Pull Latest Main & Create **<span style="color: purple;">Collaborator 2</span>**'s Feature Branch
#
# **IMPORTANT**: After cloning, **<span style="color: purple;">Collaborator 2</span>** needs to navigate into the new directory Git created.

# %%
# !cd penguin-collaboration-project

# %% [markdown]
# Create a new feature branch using the method we did before. Replace <collaborator2_name> with your name:
#
# We'll create a branch called `feature/<collaborator2_name>_add-linear-regression`.
#
# - Open the Git sidebar. You will see at the top that your **Current Branch** is `master`.
# - Click the downward arrow on the right end of the bar, and you will see a menu with a blue **New Branch** button.
# - Name your new branch `feature/<collaborator2_name>_add-linear-regression`.
# - You will now automatically be working from the new branch.

# %% [markdown]
# ## &nbsp;&nbsp; 3.4. &nbsp;&nbsp; Modify my_code.R (Add Linear Regression)
#
# Now that you're on your `feature/<collaborator2_name>_add-linear-regression` branch, you'll copy your `my_code.R` file from your `my_first_git_project` folder to your new `penguin-collaboration-project` folder.
#
# modify the `my_code.R` file to add a linear regression line to the plot. This is a distinct change from what **<span style="color: green;">Collaborator 1</span>** added.
#
# 1.  **Copy `my_code.R`**
# 2.  **Open `my_code.R`:**
# 3.  **Add a new line:** At the end of the existing `ggplot` chain (after the `labs()` line that Owner added), add the following line.
#     `+ geom_smooth(method = "lm", se = FALSE, color = "black")`
# 4.  **Save the file:** Save your changes by clicking "File" -> "Save my_code.R" or using the keyboard shortcut (`Ctrl + S` or `Cmd + S`).
# 5.  **Close the tab:** You can close the `my_code.R` editor tab if you wish.
# 6.  **Stage and commit your changes**

# %% [markdown]
# ## &nbsp;&nbsp; 3.5. &nbsp;&nbsp; Merge Your Feature into your Master branch and Push.
# Switch back to the master branch, pull the latest changes from the remote, then merge **<span style="color: purple;">Collaborator 2</span>**'s feature branch and push the updated master to the shared remote.
#
# It's crucial for **<span style="color: purple;">Collaborator 2</span>** to pull the latest main from remote *before* merging their branch. This ensures you have **<span style="color: green;">Collaborator 1</span>**'s changes locally, preventing merge conflicts.

# %% [markdown]
# ### &nbsp;&nbsp; 5.6. &nbsp;&nbsp; Delete **<span style="color: purple;">Collaborator 2</span>**'s local feature branch.
#
# First, ensure you are NOT on the branch you are trying to delete. You should not be, but it is always good to check.
#
# 1. Open the branch list in the Git sidebar again.
# 2. Right-click the feature branch (`feature/<collaborator2_name>_add-linear-regression`).
# 3. Select **Delete Branch** to keep your workspace organized.
#
# Now **<span style="color: purple;">Collaborator 2</span>** has added their changes to **<span style="color: green;">Collaborator 1</span>**'s `my_code.R` file! One last this is to check if these changes showed up for **<span style="color: green;">Collaborator 1</span>**'s Github.

# %% [markdown]
# <pre><code style="font-size: 2em; color: purple;"> END Collaborator 2
# </code></pre>
# ## It is time for **<span style="color: green;">Collaborator 1</span>** to return to their workflow now!

# %% [markdown]
# <pre><code style="font-size: 2em; color: lightb;"> BOTH COLLABORATORs
# </code></pre>

# %% [markdown]
# As a final verification, Collaborators should check their `master` branches of the `penguin-collaboration-project` on GitHub. You both should see both sets of changes reflected in the `my_code.R` file on the web interface.
#
# ## **Congratulations on your first successful collaboration on Github!**
